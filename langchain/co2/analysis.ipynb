# %%
import pandas

gdp_file = 'API_NY.GDP.MKTP.CD_DS2_en_csv_v2_5454986.csv'
co2_file = 'API_EN.ATM.CO2E.KT_DS2_en_csv_v2_5455005.csv'

gdp = pandas.read_csv(gdp_file, skiprows=4)
co2 = pandas.read_csv(co2_file, skiprows=4)

# %%
gdp.head()
# Out:
#                   Country Name Country Code     Indicator Name
# 0                        Aruba          ABW  GDP (current US$)  \
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN  \
# 1  NY.GDP.MKTP.CD  2.129152e+10  2.180944e+10  2.370806e+10  2.821128e+10
# 2  NY.GDP.MKTP.CD  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 3  NY.GDP.MKTP.CD  1.040414e+10  1.112789e+10  1.194319e+10  1.267633e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2014          2015          2016
# ...

# %%
co2.head()
# Out:
#                   Country Name Country Code      Indicator Name
# 0                        Aruba          ABW  CO2 emissions (kt)  \
# 1  Africa Eastern and Southern          AFE  CO2 emissions (kt)
# 2                  Afghanistan          AFG  CO2 emissions (kt)
# 3   Africa Western and Central          AFW  CO2 emissions (kt)
# 4                       Angola          AGO  CO2 emissions (kt)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...        2014
# 0  EN.ATM.CO2E.KT   NaN   NaN   NaN   NaN   NaN   NaN  ...         NaN  \
# 1  EN.ATM.CO2E.KT   NaN   NaN   NaN   NaN   NaN   NaN  ...  587672.097
# 2  EN.ATM.CO2E.KT   NaN   NaN   NaN   NaN   NaN   NaN  ...    4879.640
# 3  EN.ATM.CO2E.KT   NaN   NaN   NaN   NaN   NaN   NaN  ...  201660.087
# 4  EN.ATM.CO2E.KT   NaN   NaN   NaN   NaN   NaN   NaN  ...   29629.800
#
#          2015        2016        2017       2018        2019  2020  2021
# 0         NaN         NaN         NaN        NaN         NaN   NaN   NaN  \
# ...

# %%
co2.to_csv('co2.csv')
gdp.to_csv('gdp.csv')

# %%
import matplotlib.pyplot as plt

def plot_co2(country):
    years_col = [str(i) for i in range(1960, 2023)]
    country_co2 = co2[co2['Country Name'] == country][years_col]

    plt.figure()
    plt.plot(country_co2.T)
    plt.xticks(rotation=90)
    plt.grid()
    plt.show()

plot_co2('United States')

# %%
plot_co2('China')

# %%
plot_co2('Japan')

# %%
plot_co2('Brazil')
